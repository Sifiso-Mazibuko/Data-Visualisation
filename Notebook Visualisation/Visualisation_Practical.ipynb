# %% [markdown]
# ## **VISUALISATION**

# %% [markdown]
# **Get a list of the available seaborn datasets.**

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# **Load the "penguins" seaborn dataset and have a quick look at it (use 'display' or 'print').**

# %%
df = sns.load_dataset('penguins')
display(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# There are quite a few NaN values in this dataset, but since we are only focussig on visualisation for this session, let's ignore them....
#
# But now we have a sence of the different variables that we can plot.

# %% [markdown]
# # ***LINE PLOTS***

# %% [markdown]
# **Use matplotlib to plot the 'bill length' and the 'flipper length' on the same line graph.**

# %%
import matplotlib.pyplot as plt
plt.plot(df['bill_length_mm'], label = 'Bill length')
plt.plot(df['flipper_length_mm'], label = 'flipper length')
plt.grid()
plt.xlabel('Sample')
plt.ylabel('length(mm)')
plt.title('Plotting 2 variabls')
plt.legend()

# %% [markdown]
# **Now plot the 'body mass' and the 'flipper length' on the same line graph.**

# %%
plt.plot(df['body_mass_g'], label = 'Body mass')
plt.plot(df['flipper_length_mm'], label = 'flipper length')
plt.grid()
plt.xlabel('Sample')
plt.ylabel('Penguin attributes')
plt.title('Plotting 2 variabls')
plt.legend()

# %% [markdown]
# Well, that doesn't look good. And the units of each variable is different, which can easily confuse a reader.

# %% [markdown]
# **Plot the 'body mass' and the 'flipper length' again in the same graph but on different y-axis.**

# %%
fig, ax = plt.subplots()

ax.plot(df['body_mass_g'], color = 'blue', label ='Body mass(g)')

ax.set_xlabel('Penguin')

ax.set_ylabel('Mass body(g)', color = 'blue')

#second plot
ax2 = ax.twinx()

ax2.plot(df['flipper_length_mm'], color = 'orange', label = 'flipper length')

ax2.set_ylabel('flipper length(mm)', color = 'orange')

ax2.set_title('Plotting 2 variable with diffent units')

ax2.grid()

# %% [markdown]
# # ***SCATTER PLOTS***

# %% [markdown]
# **Plot the 'body mass' versus the 'flipper length' on a scatter plot.**

# %%
plt.scatter(df['body_mass_g'], df['flipper_length_mm'])
plt.xlabel('Mass body')
plt.ylabel('flipper length')
plt.title('Mass vs weight')
plt.grid()

# %% [markdown]
# The relationship between these 2 variables can now easily be deduced.

# %% [markdown]
# # ***HISTOGRAMS***

# %% [markdown]
# **Create a histogram of the 'body mass' with 80 bins.**

# %%
plt.hist(df['body_mass_g'], bins = 30) #, density = True
plt.ylabel("Number of samples")
plt.xlabel("Body Mass")
plt.title("Plotting mass and flipper length")
# Out:
# Text(0.5, 1.0, 'Plotting mass and flipper length')

# %% [markdown]
# This looks kinda noisy. It looks like there seems to be between 7 and 9 'clusters'.
# Let's play with the number of bins.

# %%
plt.hist(df['body_mass_g'], bins = 8) #, density = True
plt.ylabel("number of samples")
plt.xlabel("Body Mass")
plt.title("Plotting mass and flipper length")
# Out:
# Text(0.5, 1.0, 'Plotting mass and flipper length')

# %% [markdown]
# **Plot a new histogram with xx bins.**

# %%
plt.hist(df['body_mass_g'], bins = 12) #, density = True
plt.ylabel("Number of samples")
plt.xlabel("Body Mass")
plt.title("Plotting mass and flipper length")
# Out:
# Text(0.5, 1.0, 'Plotting mass and flipper length')

# %% [markdown]
# That is better. The most penguins seems to have a body mass between about 3200 and 4000 grams.

# %% [markdown]
# **Recreate the same histogram with 8 bins using seaborn (with the kernel density).**

# %%
import seaborn as sns
sns.set_theme()
p = sns.displot(df['body_mass_g'], bins = 30, kde = True)
p.set(xlabel = 'Mass rangle', ylabel = 'Mass of penguin', title  = 'Plotting body mass')

# %% [markdown]
# The peak seems to be around 3600 grams.

# %% [markdown]
# # ***BAR PLOTS***

# %% [markdown]
# **Load the "diamonds" seaborn dataset.**

# %%
df2 = sns.load_dataset('diamonds')
display(df2)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# **Create a bar plot with seaborn** where "cut" is on the x-axis, "carat" is on the y-axis and the bars (hue) represent the "color".

# %%
sns.barplot(x = 'cut', y='carat', hue = 'color', data=df2)
plt.legend(bbox_to_anchor = (1,0.5), loc = 'center left')

# %% [markdown]
# # ***HEAT MAPS***

# %% [markdown]
# **Create a heatmap looking at 'cut' and 'color'.** Hint: use groupby and have a look to make sure that the data looks correct.

# %%
data = df2.groupby(['cut', 'color']).size().unstack(level =0)
display(data)
sns.heatmap(data, annot= True, fmt = '.4g')
# Out:
# cut    Ideal  Premium  Very Good  Good  Fair
# color
# D       2834     1603       1513   662   163
# E       3903     2337       2400   933   224
# F       3826     2331       2164   909   312
# G       4884     2924       2299   871   314
# H       3115     2360       1824   702   303
# I       2093     1428       1204   522   175
# J        896      808        678   307   119
# <Axes: xlabel='cut', ylabel='color'>

# %% [markdown]
# # ***PIE PLOTS***

# %% [markdown]
# **Create a Pie plot looking at 'cut' and 'color'. Visualise the color breakdown for a 'Fair' cut.**

# %%
dataple = datapie.transpose()

# %% [markdown]
# **Finally create a Pie plot looking at 'cut' breakdown for a specific color ('G').**

# %%
plot = datapie.plot.pie(y = 'G')

# %% [markdown]
# ## **DONE!!!!!**
